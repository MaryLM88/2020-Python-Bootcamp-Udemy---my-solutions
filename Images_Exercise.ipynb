# %%
from PIL import Image

# %%
matrix = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
mask.putalpha(100)

# %%
mask = mask.resize((1015, 559))

# %%
matrix.paste(mask,(0,0,1015, 559),mask)

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x19EFF1B02E0>
